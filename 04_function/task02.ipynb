# %%
import urllib
import datetime

def save_url_content(url):
    response =urllib.request.urlopen(url)
    dt_now = datetime.datetime.now()
    output_file = dt_now.strftime('%Y%m%d_%H%M%S.txt')
    with open(output_file, "w", encoding="utf-8") as file:
        file.write(response.read().decode("utf-8")[:500])
    
    return output_file


url = input("URLを入力してください: ")
file_name = save_url_content(url)
print(f"Content saved in: {file_name}")
# Out:
# Content saved in: 20260218_101442.txt
