# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))
# Out:
# {'_request_id': 'req_3928d0a8e297477f8a916436c6abdbc0',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを効果的に活用するためのポイントはいくつかあります。以下にいくつかの重要な点を挙げます。\n\n1. **明確な指示を与える**: 言語モデルは、具体的でわかりやすい指示を受けた際に、より良い結果を生成します。曖昧な質問や指示は避け、必要な情報を明確にすることが重要です。\n\n2. **コンテキストを提供する**: モデルに関連する情報や背景を与えることで、より適切な応答が得られます。例えば、特定のトピックについて話している場合、そのトピックに関する前提知識を提供することが有効です。\n\n3. **繰り返し利用する**: 言語モデルは、試行錯誤を通じて改善されることが多いです。異なる質問やアプローチを試すことで、より良い結果を引き出せることがあります。\n\n4. **フィードバックを与える**: モデルの応答に対してフィードバックを提供することも重要です。不適切な応答があった場合、その理由を具体的に示すことで、より良い結果が得られる可能性があります。\n\n5. **倫理的な使い方を心がける**: 言語モデルを使用する際には、プライバシーや倫理に配慮し、不適切なコンテンツや差別的な表現を避けるよう努めるべきです。また、誤情報を拡散しないよう注意が必要です。\n\n6. **利用目的を明確にする**: 何のために言語モデルを使うのか、その目的を明確にすることで、適切な使い方ができるようになります。リサーチ、クリエイティブな作業、カスタマーサポートなど、目的に応じたアプローチを選択することが大切です。\n\n7. **限界を理解する**: 言語モデルには限界があり、全ての質問に正確に応えるわけではありません。特に専門的な分野や最新の情報、個別のケースについては注意が必要です。\n\n以上のポイントを踏まえながら、言語モデルを効果的に利用することで、有益な成果を得ることができるでしょう。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1771551611,
#  'id': 'chatcmpl-DB9n14AYmIjX5ghPCsyrOvA0Itr2b',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_373a14eb6f',
#  'usage': CompletionUsage(completion_tokens=556, prompt_tokens=18, total_tokens=574, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}

# %%
# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 言語モデルを効果的に活用するためのポイントはいくつかあります。以下にいくつかの重要な点を挙げます。
#
# 1. **明確な指示を与える**: 言語モデルは、具体的でわかりやすい指示を受けた際に、より良い結果を生成します。曖昧な質問や指示は避け、必要な情報を明確にすることが重要です。
#
# 2. **コンテキストを提供する**: モデルに関連する情報や背景を与えることで、より適切な応答が得られます。例えば、特定のトピックについて話している場合、そのトピックに関する前提知識を提供することが有効です。
#
# 3. **繰り返し利用する**: 言語モデルは、試行錯誤を通じて改善されることが多いです。異なる質問やアプローチを試すことで、より良い結果を引き出せることがあります。
#
# 4. **フィードバックを与える**: モデルの応答に対してフィードバックを提供することも重要です。不適切な応答があった場合、その理由を具体的に示すことで、より良い結果が得られる可能性があります。
#
# 5. **倫理的な使い方を心がける**: 言語モデルを使用する際には、プライバシーや倫理に配慮し、不適切なコンテンツや差別的な表現を避けるよう努めるべきです。また、誤情報を拡散しないよう注意が必要です。
#
# 6. **利用目的を明確にする**: 何のために言語モデルを使うのか、その目的を明確にすることで、適切な使い方ができるようになります。リサーチ、クリエイティブな作業、カスタマーサポートなど、目的に応じたアプローチを選択することが大切です。
#
# 7. **限界を理解する**: 言語モデルには限界があり、全ての質問に正確に応えるわけではありません。特に専門的な分野や最新の情報、個別のケースについては注意が必要です。
#
# 以上のポイントを踏まえながら、言語モデルを効果的に利用することで、有益な成果を得ることができるでしょう。

# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"


# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ]
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略には、以下のステップを考慮することが重要です。
#
# ### 1. マーケットリサーチ
# - **ターゲットオーディエンスの特定**: 新製品の主な顧客層を調査し、どのようなニーズや課題を抱えているかを理解します。
# - **競合分析**: 競合他社の製品、マーケティング手法、価格設定を調査し、差別化ポイントを見つけます。
#
# ### 2. ブランドポジショニング
# - **ユニークセリングプロポジション (USP)**: 新製品の特長や利点を明確にし、この製品がどのように顧客のニーズを満たすかを定義します。
# - **ブランドストーリー**: 製品の背景や開発ストーリーを通じて、情感に訴えるメッセージを作成します。
#
# ### 3. プレローンチマーケティング
# - **ティーザーキャンペーン**: ソーシャルメディアやメルマガ等を使って、製品の一部や特徴を小出しにし、期待感を高めます。
# - **インフルエンサーとの連携**: ターゲットオーディエンスに影響力のあるインフルエンサーと提携し、彼らを通じて製品を広めます。
#
# ### 4. 発売イベントの開催
# - **ローンチイベント**: 発売日に合わせてイベントを開催し、参加者に製品を体験してもらいます。オンラインとオフライン両方の形式が考えられます。
# - **デモンストレーション**: 製品の使い方や利点を実演することで、実際の魅力を伝えます。
#
# ### 5. マルチチャネルプロモーション
# - **ソーシャルメディア広告**: Facebook、Instagram、Twitterなどで広告を出し、ビジュアルなコンテンツで訴求します。
# - **コンテンツマーケティング**: ブログや動画を通じて製品の教育コンテンツを提供し、顧客の信頼を築きます。
# - **Eメールキャンペーン**: 顧客リストに向けて、製品の発売情報や特典、限定オファーを送信します。
#
# ### 6. フィードバックとデータの収集
# - **顧客の反応分析**: 製品発売後、顧客からのフィードバックを収集し、製品の改善点やマーケティング戦略の調整に役立てます。
# - **販売データの追跡**: 発売後の販売データを分析し、どのチャネルや手法が最も効果的だったかを評価します。
#
# ### 7. 継続的な関係構築
# - **カスタマーサポートの強化**: 購入後の顧客サポートを充実させ、顧客満足度を高めることがリピーターの獲得につながります。
# - **リテンションキャンペーン**: 購入した顧客に対してフォローアップを行い、次回購入を促す戦略を導入します。
#
# これらのステップを組み合わせることで、新製品の発売を強力にサポートするマーケティング戦略を構築することができます。計画の段階から実行まで、継続的に評価と改善を行うことが重要です。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本には多くの魅力があります。以下はいくつかのポイントです。
#
# ### 1. 自然美
# 日本は四季があるため、春には桜、夏には緑豊かな山々、秋には紅葉、冬には雪景色と、多様な自然の美しさを楽しむことができます。例えば、富士山や北海道の大自然などが挙げられます。
#
# ### 2.
# --------------------
# もちろん、日本は魅力的な文化、自然、美味しい食べ物、歴史的な名所など多様な魅力を持っています。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 様々なお祭りが四季折々に開催され、伝統芸能や神輿（みこし）などを楽しめます。例えば、青森
# --------------------
# 日本は魅力的な文化や自然、歴史、色々な体験が詰まった国です。以下にいくつかのポイントを挙げて、日本の魅力を紹介します。
#
# ### 1. 豊かな文化と伝統
# - **芸術・音楽**: 日本の伝統的な芸術形態には、歌舞伎、能、和太鼓などがあります。また、現代のポップカル

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=2.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# 日本には多くの魅力があります。いくつかを紹介しますね。
#
# ### 1. 豊かな文化遺産
# 日本は古代からの歴史と伝統が息づいています。京都や奈良などの都市には、数多くの寺院や神社、伝統的な街並みが残っており、世界遺産にも登録された場所が多数あります。
#
# ### 2. 美しい自然景観
# --------------------
# もちろん、日本の魅力は多岐にわたります。以下にいくつかのポイントを挙げてみます。
#
# ### 1. 文化と伝統
# 日本には古代から続くさまざまな文化や伝統があります。例えば、茶道、華道、剣道など、独自の技術や思想が重んじられています。また、毎年行われる祭りも多彩で、地域
# --------------------
# もちろんです！日本には数多くの魅力がありますが、いくつかを紹介します。
#
# 1. **文化と歴史**: 日本は古代からの豊かな文化と歴史を持っています。お寺や神社、伝統的な祭り（例えば、京都の祇園祭）など、訪れることで日本の深い歴史に触れられます。
#
# 2. **美しい自然**: 富士山や

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは！Aさん、元気ですか？
# --------------------
# B:こんにちは！Aさん、元気ですか？
# --------------------
# B:こんにちは、Aさん！お元気ですか？

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを効果的に使用するためのポイントはいくつかあります。以下にいくつか挙げます：
#
# 1. **明確な目的を設定する**: 言語モデルを使用する目的を明確にすることで、求める結果を得やすくなります。例えば、情報の検索、文章の生成、翻訳など、用途によってアプローチが異なります。
#
# 2. **具体的な入力をする**: モデルに与える入力は具体的かつ明確であるほどよい結果が得られやすいです。あいまいな質問や指示では期待する回答が得られないことがあります。
#
# 3. **文脈を提供する**: 特に複雑なタスクでは、適切な文脈を提供することが重要です。背景情報や関連する詳細を含めることで、より的確な応答を引き出せます。
#
# 4. **多様なリクエストを試す**: モデルには複数のリクエストスタイルを試してみることをお勧めします。同じ質問でも言い回しを変えることで、異なる視点からの応答を得ることができます。
#
# 5. **モデルの限界を理解する**: 言語モデルは完璧ではありません。誤った情報や不適切な応答をする可能性があるため、その限界を理解し、結果を鵜呑みにしないことが重要です。
#
# 6. **フィードバックを活用する**: 得られた応答に対してフィードバックを行うことで、次回以降の応答が改善される場合があります。特に対話型のシステムでは、フォローアップの質問が有効です。
#
# 7. **倫理的な配慮**: 言語モデルを使用する際は、プライバシーやバイアス、誤情報の拡散などの倫理的問題についても考慮することが重要です。
#
# これらのポイントを心がけることで、言語モデルをより効果的に活用できるでしょう。
