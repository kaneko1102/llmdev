# %%
price = int(input("税抜き価格を入力してください: "))

total_price = int(price * 1.1)
postage = 350

if total_price >= 2000:
    print("送料は無料です")
else:
    print(f"送料は{postage}円です")
    total_price += postage

print(f"送料込み税込価格は{total_price}円です")
# Out:
# 送料は無料です
# 送料込み税込価格は2200円です
