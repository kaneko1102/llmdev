# %%
amount = int(input("初期投資額を入力してください: "))
annual_interest_rate = int(input("年利（パーセンテージ）を入力してください: "))

for i in range(10):
    amount = amount * (1 + (annual_interest_rate / 100))

print(f"10年後の金額: {amount:.2f}")
# Out:
# 10年後の金額: 1628.89
