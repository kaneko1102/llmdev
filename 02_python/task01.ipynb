# %%
name = "金子卓矢"
age = 26

print("はじめまして、", name, "と申します。")
print("年齢は", age, "歳です。来年は", age + 1, "歳になります。")
print("よろしくお願いします。")
# Out:
# はじめまして、 金子卓矢 と申します。
# 年齢は 26 歳です。来年は 27 歳になります。
# よろしくお願いします。
