# %%
grades = [85, 90, 78, 92, 88]

average = sum(grades) / len(grades)
min_grade = min(grades)
max_grade = max(grades)
num_average_or_above = len([i for i in grades if i >= average])

print(f"平均点: {average}")
print(f"最高点: {max_grade}")
print(f"最低点: {min_grade}")
print(f"平均以上の学生数: {num_average_or_above}")
# Out:
# 平均点: 86.6
# 最高点: 92
# 最低点: 78
# 平均以上の学生数: 3
